# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import xgboost as xgb
import warnings

warnings.filterwarnings('ignore')

train_data = "train.csv"
df = pd.read_csv(train_data)

df.isnull().sum()
df['num_sold'].fillna(0, inplace=True)
df.isnull().sum()

X = df.drop('num_sold', axis=1)

y = df['num_sold']

y.head()
# split X and y into training and testing sets

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.15, random_state = 0)
# import XGBClassifier
from xgboost import XGBClassifier


# declare parameters
params = {
            'objective':'reg:squarederror',
            'max_depth': 4,
            'alpha': 10,
            'learning_rate': 0.1,
            'n_estimators':100
        }
            
            
            
# instantiate the classifier 
xgb_clf = XGBClassifier(**params)

from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
y_train = le.fit_transform(y_train)


# fit the classifier to the training data
xgb_clf.fit(X_train, y_train)

# make predictions on test data
y_pred = xgb_clf.predict(X_test)

# check accuracy score
from sklearn.metrics import accuracy_score

print('XGBoost model accuracy score: {0:0.4f}'. format(accuracy_score(y_test, y_pred)))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\HP\Downloads\playground-series\.venv\Lib\site-packages\xgboost\data.py:407, in pandas_feature_info(data, meta, feature_names, feature_types, enable_categorical)
#     406 try:
# --> 407     new_feature_types.append(_pandas_dtype_mapper[dtype.name])
#     408 except KeyError:
#
# KeyError: 'object'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 51
#      47 y_train = le.fit_transform(y_train)
#      50 # fit the classifier to the training data
# ---> 51 xgb_clf.fit(X_train, y_train)
#      53 # make predictions on test data
#      54 y_pred = xgb_clf.predict(X_test)
#
# File c:\Users\HP\Downloads\playground-series\.venv\Lib\site-packages\xgboost\core.py:729, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     727 for k, arg in zip(sig.parameters, args):
#     728     kwargs[k] = arg
# --> 729 return func(**kwargs)
#
# File c:\Users\HP\Downloads\playground-series\.venv\Lib\site-packages\xgboost\sklearn.py:1663, in XGBClassifier.fit(self, X, y, sample_weight, base_margin, eval_set, verbose, xgb_model, sample_weight_eval_set, base_margin_eval_set, feature_weights)
#    1658     params["num_class"] = self.n_classes_
#    1660 model, metric, params, feature_weights = self._configure_fit(
#    1661     xgb_model, params, feature_weights
#    1662 )
# -> 1663 train_dmatrix, evals = _wrap_evaluation_matrices(
#    1664     missing=self.missing,
#    1665     X=X,
#    1666     y=y,
#    1667     group=None,
#    1668     qid=None,
#    1669     sample_weight=sample_weight,
#    1670     base_margin=base_margin,
#    1671     feature_weights=feature_weights,
#    1672     eval_set=eval_set,
#    1673     sample_weight_eval_set=sample_weight_eval_set,
#    1674     base_margin_eval_set=base_margin_eval_set,
#    1675     eval_group=None,
#    1676     eval_qid=None,
#    1677     create_dmatrix=self._create_dmatrix,
#    1678     enable_categorical=self.enable_categorical,
#    1679     feature_types=self.feature_types,
#    1680 )
#    1682 self._Booster = train(
#    1683     params,
#    1684     train_dmatrix,
#    (...)   1693     callbacks=self.callbacks,
#    1694 )
#    1696 if not callable(self.objective):
#
# File c:\Users\HP\Downloads\playground-series\.venv\Lib\site-packages\xgboost\sklearn.py:628, in _wrap_evaluation_matrices(missing, X, y, group, qid, sample_weight, base_margin, feature_weights, eval_set, sample_weight_eval_set, base_margin_eval_set, eval_group, eval_qid, create_dmatrix, enable_categorical, feature_types)
#     607 def _wrap_evaluation_matrices(
#     608     *,
#     609     missing: float,
#    (...)    624     feature_types: Optional[FeatureTypes],
#     625 ) -> Tuple[Any, List[Tuple[Any, str]]]:
#     626     """Convert array_like evaluation matrices into DMatrix.  Perform validation on the
#     627     way."""
# --> 628     train_dmatrix = create_dmatrix(
#     629         data=X,
#     630         label=y,
#     631         group=group,
#     632         qid=qid,
#     633         weight=sample_weight,
#     634         base_margin=base_margin,
#     635         feature_weights=feature_weights,
#     636         missing=missing,
#     637         enable_categorical=enable_categorical,
#     638         feature_types=feature_types,
#     639         ref=None,
#     640     )
#     642     n_validation = 0 if eval_set is None else len(eval_set)
#     644     def validate_or_none(meta: Optional[Sequence], name: str) -> Sequence:
#
# File c:\Users\HP\Downloads\playground-series\.venv\Lib\site-packages\xgboost\sklearn.py:1137, in XGBModel._create_dmatrix(self, ref, **kwargs)
#    1135 if _can_use_qdm(self.tree_method, self.device) and self.booster != "gblinear":
#    1136     try:
# -> 1137         return QuantileDMatrix(
#    1138             **kwargs, ref=ref, nthread=self.n_jobs, max_bin=self.max_bin
#    1139         )
#    1140     except TypeError:  # `QuantileDMatrix` supports lesser types than DMatrix
#    1141         pass
#
# File c:\Users\HP\Downloads\playground-series\.venv\Lib\site-packages\xgboost\core.py:729, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     727 for k, arg in zip(sig.parameters, args):
#     728     kwargs[k] = arg
# --> 729 return func(**kwargs)
#
# File c:\Users\HP\Downloads\playground-series\.venv\Lib\site-packages\xgboost\core.py:1614, in QuantileDMatrix.__init__(self, data, label, weight, base_margin, missing, silent, feature_names, feature_types, nthread, max_bin, ref, group, qid, label_lower_bound, label_upper_bound, feature_weights, enable_categorical, max_quantile_batches, data_split_mode)
#    1594     if any(
#    1595         info is not None
#    1596         for info in (
#    (...)   1607         )
#    1608     ):
#    1609         raise ValueError(
#    1610             "If data iterator is used as input, data like label should be "
#    1611             "specified as batch argument."
#    1612         )
# -> 1614 self._init(
#    1615     data,
#    1616     ref=ref,
#    1617     label=label,
#    1618     weight=weight,
#    1619     base_margin=base_margin,
#    1620     group=group,
#    1621     qid=qid,
#    1622     label_lower_bound=label_lower_bound,
#    1623     label_upper_bound=label_upper_bound,
#    1624     feature_weights=feature_weights,
#    1625     feature_names=feature_names,
#    1626     feature_types=feature_types,
#    1627     enable_categorical=enable_categorical,
#    1628     max_quantile_blocks=max_quantile_batches,
#    1629 )
#
# File c:\Users\HP\Downloads\playground-series\.venv\Lib\site-packages\xgboost\core.py:1678, in QuantileDMatrix._init(self, data, ref, enable_categorical, max_quantile_blocks, **meta)
#    1663 config = make_jcargs(
#    1664     nthread=self.nthread,
#    1665     missing=self.missing,
#    1666     max_bin=self.max_bin,
#    1667     max_quantile_blocks=max_quantile_blocks,
#    1668 )
#    1669 ret = _LIB.XGQuantileDMatrixCreateFromCallback(
#    1670     None,
#    1671     it.proxy.handle,
#    (...)   1676     ctypes.byref(handle),
#    1677 )
# -> 1678 it.reraise()
#    1679 # delay check_call to throw intermediate exception first
#    1680 _check_call(ret)
#
# File c:\Users\HP\Downloads\playground-series\.venv\Lib\site-packages\xgboost\core.py:572, in DataIter.reraise(self)
#     570 exc = self._exception
#     571 self._exception = None
# --> 572 raise exc
#
# File c:\Users\HP\Downloads\playground-series\.venv\Lib\site-packages\xgboost\core.py:553, in DataIter._handle_exception(self, fn, dft_ret)
#     550     return dft_ret
#     552 try:
# --> 553     return fn()
#     554 except Exception as e:  # pylint: disable=broad-except
#     555     # Defer the exception in order to return 0 and stop the iteration.
#     556     # Exception inside a ctype callback function has no effect except
#     557     # for printing to stderr (doesn't stop the execution).
#     558     tb = sys.exc_info()[2]
#
# File c:\Users\HP\Downloads\playground-series\.venv\Lib\site-packages\xgboost\core.py:640, in DataIter._next_wrapper.<locals>.<lambda>()
#     638     self._temporary_data = None
#     639 # pylint: disable=not-callable
# --> 640 return self._handle_exception(lambda: int(self.next(input_data)), 0)
#
# File c:\Users\HP\Downloads\playground-series\.venv\Lib\site-packages\xgboost\data.py:1654, in SingleBatchInternalIter.next(self, input_data)
#    1652     return False
#    1653 self.it += 1
# -> 1654 input_data(**self.kwargs)
#    1655 return True
#
# File c:\Users\HP\Downloads\playground-series\.venv\Lib\site-packages\xgboost\core.py:729, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     727 for k, arg in zip(sig.parameters, args):
#     728     kwargs[k] = arg
# --> 729 return func(**kwargs)
#
# File c:\Users\HP\Downloads\playground-series\.venv\Lib\site-packages\xgboost\core.py:620, in DataIter._next_wrapper.<locals>.input_data(data, feature_names, feature_types, **kwargs)
#     618     new, cat_codes, feature_names, feature_types = self._temporary_data
#     619 else:
# --> 620     new, cat_codes, feature_names, feature_types = _proxy_transform(
#     621         data,
#     622         feature_names,
#     623         feature_types,
#     624         self._enable_categorical,
#     625     )
#     626 # Stage the data, meta info are copied inside C++ MetaInfo.
#     627 self._temporary_data = (new, cat_codes, feature_names, feature_types)
#
# File c:\Users\HP\Downloads\playground-series\.venv\Lib\site-packages\xgboost\data.py:1707, in _proxy_transform(data, feature_names, feature_types, enable_categorical)
#    1705     return df_pa, None, feature_names, feature_types
#    1706 if _is_pandas_df(data):
# -> 1707     df, feature_names, feature_types = _transform_pandas_df(
#    1708         data, enable_categorical, feature_names, feature_types
#    1709     )
#    1710     return df, None, feature_names, feature_types
#    1711 raise TypeError("Value type is not supported for data iterator:" + str(type(data)))
#
# File c:\Users\HP\Downloads\playground-series\.venv\Lib\site-packages\xgboost\data.py:640, in _transform_pandas_df(data, enable_categorical, feature_names, feature_types, meta)
#     637 if meta and len(data.columns) > 1 and meta not in _matrix_meta:
#     638     raise ValueError(f"DataFrame for {meta} cannot have multiple columns")
# --> 640 feature_names, feature_types = pandas_feature_info(
#     641     data, meta, feature_names, feature_types, enable_categorical
#     642 )
#     644 arrays = pandas_transform_data(data)
#     645 return PandasTransformed(arrays), feature_names, feature_types
#
# File c:\Users\HP\Downloads\playground-series\.venv\Lib\site-packages\xgboost\data.py:409, in pandas_feature_info(data, meta, feature_names, feature_types, enable_categorical)
#     407             new_feature_types.append(_pandas_dtype_mapper[dtype.name])
#     408         except KeyError:
# --> 409             _invalid_dataframe_dtype(data)
#     411 if feature_types is None and meta is None:
#     412     feature_types = new_feature_types
#
# File c:\Users\HP\Downloads\playground-series\.venv\Lib\site-packages\xgboost\data.py:372, in _invalid_dataframe_dtype(data)
#     370 type_err = "DataFrame.dtypes for data must be int, float, bool or category."
#     371 msg = f"""{type_err} {_ENABLE_CAT_ERR} {err}"""
# --> 372 raise ValueError(msg)
#
# ValueError: DataFrame.dtypes for data must be int, float, bool or category. When categorical type is supplied, the experimental DMatrix parameter`enable_categorical` must be set to `True`.  Invalid columns:date: object, country: object, store: object, product: object

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import xgboost as xgb
import warnings

warnings.filterwarnings('ignore')

train_data = "train.csv"
df = pd.read_csv(train_data)

df.isnull().sum()
df['num_sold'].fillna(0, inplace=True)
df.isnull().sum()

X = df.drop('num_sold', axis=1)

y = df['num_sold']

y.head()
# split X and y into training and testing sets

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.15, random_state = 0)
# import XGBClassifier
from xgboost import XGBClassifier


# declare parameters
params = {
            'objective':'reg:squarederror',
            'max_depth': 4,
            'alpha': 10,
            'learning_rate': 0.1,
            'n_estimators':100
        }
            
            
            
# instantiate the classifier 
xgb_clf = XGBClassifier(**params)

from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
y_train = le.fit_transform(y_train)


# fit the classifier to the training data
xgb_clf.fit(X_train, y_train)

# make predictions on test data
y_pred = xgb_clf.predict(X_test)

# check accuracy score
from sklearn.metrics import accuracy_score

print('XGBoost model accuracy score: {0:0.4f}'. format(accuracy_score(y_test, y_pred)))
# Out:
# Cell was canceled due to an error in a previous cell.

# %% [markdown]
# Restarted .venv (Python 3.13.1)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import xgboost as xgb
import warnings

warnings.filterwarnings('ignore')

train_data = "train.csv"
df = pd.read_csv(train_data)

df.isnull().sum()
df['num_sold'].fillna(0, inplace=True)
df.isnull().sum()

X = df.drop('num_sold', axis=1)

y = df['num_sold']

y.head()
# split X and y into training and testing sets

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.15, random_state = 0)
# import XGBClassifier
from xgboost import XGBClassifier


# declare parameters
params = {
            'objective':'reg:squarederror',
            'max_depth': 4,
            'alpha': 10,
            'learning_rate': 0.1,
            'n_estimators':100
        }
            
            
            
# instantiate the classifier 
xgb_clf = XGBClassifier(**params)

from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
y_train = le.fit_transform(y_train)


# fit the classifier to the training data
xgb_clf.fit(X_train, y_train)

# make predictions on test data
y_pred = xgb_clf.predict(X_test)

# check accuracy score
from sklearn.metrics import accuracy_score

print('XGBoost model accuracy score: {0:0.4f}'. format(accuracy_score(y_test, y_pred)))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\HP\Downloads\playground-series\.venv\Lib\site-packages\xgboost\data.py:407, in pandas_feature_info(data, meta, feature_names, feature_types, enable_categorical)
#     406 try:
# --> 407     new_feature_types.append(_pandas_dtype_mapper[dtype.name])
#     408 except KeyError:
#
# KeyError: 'object'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 51
#      47 y_train = le.fit_transform(y_train)
#      50 # fit the classifier to the training data
# ---> 51 xgb_clf.fit(X_train, y_train)
#      53 # make predictions on test data
#      54 y_pred = xgb_clf.predict(X_test)
#
# File c:\Users\HP\Downloads\playground-series\.venv\Lib\site-packages\xgboost\core.py:729, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     727 for k, arg in zip(sig.parameters, args):
#     728     kwargs[k] = arg
# --> 729 return func(**kwargs)
#
# File c:\Users\HP\Downloads\playground-series\.venv\Lib\site-packages\xgboost\sklearn.py:1663, in XGBClassifier.fit(self, X, y, sample_weight, base_margin, eval_set, verbose, xgb_model, sample_weight_eval_set, base_margin_eval_set, feature_weights)
#    1658     params["num_class"] = self.n_classes_
#    1660 model, metric, params, feature_weights = self._configure_fit(
#    1661     xgb_model, params, feature_weights
#    1662 )
# -> 1663 train_dmatrix, evals = _wrap_evaluation_matrices(
#    1664     missing=self.missing,
#    1665     X=X,
#    1666     y=y,
#    1667     group=None,
#    1668     qid=None,
#    1669     sample_weight=sample_weight,
#    1670     base_margin=base_margin,
#    1671     feature_weights=feature_weights,
#    1672     eval_set=eval_set,
#    1673     sample_weight_eval_set=sample_weight_eval_set,
#    1674     base_margin_eval_set=base_margin_eval_set,
#    1675     eval_group=None,
#    1676     eval_qid=None,
#    1677     create_dmatrix=self._create_dmatrix,
#    1678     enable_categorical=self.enable_categorical,
#    1679     feature_types=self.feature_types,
#    1680 )
#    1682 self._Booster = train(
#    1683     params,
#    1684     train_dmatrix,
#    (...)   1693     callbacks=self.callbacks,
#    1694 )
#    1696 if not callable(self.objective):
#
# File c:\Users\HP\Downloads\playground-series\.venv\Lib\site-packages\xgboost\sklearn.py:628, in _wrap_evaluation_matrices(missing, X, y, group, qid, sample_weight, base_margin, feature_weights, eval_set, sample_weight_eval_set, base_margin_eval_set, eval_group, eval_qid, create_dmatrix, enable_categorical, feature_types)
#     607 def _wrap_evaluation_matrices(
#     608     *,
#     609     missing: float,
#    (...)    624     feature_types: Optional[FeatureTypes],
#     625 ) -> Tuple[Any, List[Tuple[Any, str]]]:
#     626     """Convert array_like evaluation matrices into DMatrix.  Perform validation on the
#     627     way."""
# --> 628     train_dmatrix = create_dmatrix(
#     629         data=X,
#     630         label=y,
#     631         group=group,
#     632         qid=qid,
#     633         weight=sample_weight,
#     634         base_margin=base_margin,
#     635         feature_weights=feature_weights,
#     636         missing=missing,
#     637         enable_categorical=enable_categorical,
#     638         feature_types=feature_types,
#     639         ref=None,
#     640     )
#     642     n_validation = 0 if eval_set is None else len(eval_set)
#     644     def validate_or_none(meta: Optional[Sequence], name: str) -> Sequence:
#
# File c:\Users\HP\Downloads\playground-series\.venv\Lib\site-packages\xgboost\sklearn.py:1137, in XGBModel._create_dmatrix(self, ref, **kwargs)
#    1135 if _can_use_qdm(self.tree_method, self.device) and self.booster != "gblinear":
#    1136     try:
# -> 1137         return QuantileDMatrix(
#    1138             **kwargs, ref=ref, nthread=self.n_jobs, max_bin=self.max_bin
#    1139         )
#    1140     except TypeError:  # `QuantileDMatrix` supports lesser types than DMatrix
#    1141         pass
#
# File c:\Users\HP\Downloads\playground-series\.venv\Lib\site-packages\xgboost\core.py:729, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     727 for k, arg in zip(sig.parameters, args):
#     728     kwargs[k] = arg
# --> 729 return func(**kwargs)
#
# File c:\Users\HP\Downloads\playground-series\.venv\Lib\site-packages\xgboost\core.py:1614, in QuantileDMatrix.__init__(self, data, label, weight, base_margin, missing, silent, feature_names, feature_types, nthread, max_bin, ref, group, qid, label_lower_bound, label_upper_bound, feature_weights, enable_categorical, max_quantile_batches, data_split_mode)
#    1594     if any(
#    1595         info is not None
#    1596         for info in (
#    (...)   1607         )
#    1608     ):
#    1609         raise ValueError(
#    1610             "If data iterator is used as input, data like label should be "
#    1611             "specified as batch argument."
#    1612         )
# -> 1614 self._init(
#    1615     data,
#    1616     ref=ref,
#    1617     label=label,
#    1618     weight=weight,
#    1619     base_margin=base_margin,
#    1620     group=group,
#    1621     qid=qid,
#    1622     label_lower_bound=label_lower_bound,
#    1623     label_upper_bound=label_upper_bound,
#    1624     feature_weights=feature_weights,
#    1625     feature_names=feature_names,
#    1626     feature_types=feature_types,
#    1627     enable_categorical=enable_categorical,
#    1628     max_quantile_blocks=max_quantile_batches,
#    1629 )
#
# File c:\Users\HP\Downloads\playground-series\.venv\Lib\site-packages\xgboost\core.py:1678, in QuantileDMatrix._init(self, data, ref, enable_categorical, max_quantile_blocks, **meta)
#    1663 config = make_jcargs(
#    1664     nthread=self.nthread,
#    1665     missing=self.missing,
#    1666     max_bin=self.max_bin,
#    1667     max_quantile_blocks=max_quantile_blocks,
#    1668 )
#    1669 ret = _LIB.XGQuantileDMatrixCreateFromCallback(
#    1670     None,
#    1671     it.proxy.handle,
#    (...)   1676     ctypes.byref(handle),
#    1677 )
# -> 1678 it.reraise()
#    1679 # delay check_call to throw intermediate exception first
#    1680 _check_call(ret)
#
# File c:\Users\HP\Downloads\playground-series\.venv\Lib\site-packages\xgboost\core.py:572, in DataIter.reraise(self)
#     570 exc = self._exception
#     571 self._exception = None
# --> 572 raise exc
#
# File c:\Users\HP\Downloads\playground-series\.venv\Lib\site-packages\xgboost\core.py:553, in DataIter._handle_exception(self, fn, dft_ret)
#     550     return dft_ret
#     552 try:
# --> 553     return fn()
#     554 except Exception as e:  # pylint: disable=broad-except
#     555     # Defer the exception in order to return 0 and stop the iteration.
#     556     # Exception inside a ctype callback function has no effect except
#     557     # for printing to stderr (doesn't stop the execution).
#     558     tb = sys.exc_info()[2]
#
# File c:\Users\HP\Downloads\playground-series\.venv\Lib\site-packages\xgboost\core.py:640, in DataIter._next_wrapper.<locals>.<lambda>()
#     638     self._temporary_data = None
#     639 # pylint: disable=not-callable
# --> 640 return self._handle_exception(lambda: int(self.next(input_data)), 0)
#
# File c:\Users\HP\Downloads\playground-series\.venv\Lib\site-packages\xgboost\data.py:1654, in SingleBatchInternalIter.next(self, input_data)
#    1652     return False
#    1653 self.it += 1
# -> 1654 input_data(**self.kwargs)
#    1655 return True
#
# File c:\Users\HP\Downloads\playground-series\.venv\Lib\site-packages\xgboost\core.py:729, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     727 for k, arg in zip(sig.parameters, args):
#     728     kwargs[k] = arg
# --> 729 return func(**kwargs)
#
# File c:\Users\HP\Downloads\playground-series\.venv\Lib\site-packages\xgboost\core.py:620, in DataIter._next_wrapper.<locals>.input_data(data, feature_names, feature_types, **kwargs)
#     618     new, cat_codes, feature_names, feature_types = self._temporary_data
#     619 else:
# --> 620     new, cat_codes, feature_names, feature_types = _proxy_transform(
#     621         data,
#     622         feature_names,
#     623         feature_types,
#     624         self._enable_categorical,
#     625     )
#     626 # Stage the data, meta info are copied inside C++ MetaInfo.
#     627 self._temporary_data = (new, cat_codes, feature_names, feature_types)
#
# File c:\Users\HP\Downloads\playground-series\.venv\Lib\site-packages\xgboost\data.py:1707, in _proxy_transform(data, feature_names, feature_types, enable_categorical)
#    1705     return df_pa, None, feature_names, feature_types
#    1706 if _is_pandas_df(data):
# -> 1707     df, feature_names, feature_types = _transform_pandas_df(
#    1708         data, enable_categorical, feature_names, feature_types
#    1709     )
#    1710     return df, None, feature_names, feature_types
#    1711 raise TypeError("Value type is not supported for data iterator:" + str(type(data)))
#
# File c:\Users\HP\Downloads\playground-series\.venv\Lib\site-packages\xgboost\data.py:640, in _transform_pandas_df(data, enable_categorical, feature_names, feature_types, meta)
#     637 if meta and len(data.columns) > 1 and meta not in _matrix_meta:
#     638     raise ValueError(f"DataFrame for {meta} cannot have multiple columns")
# --> 640 feature_names, feature_types = pandas_feature_info(
#     641     data, meta, feature_names, feature_types, enable_categorical
#     642 )
#     644 arrays = pandas_transform_data(data)
#     645 return PandasTransformed(arrays), feature_names, feature_types
#
# File c:\Users\HP\Downloads\playground-series\.venv\Lib\site-packages\xgboost\data.py:409, in pandas_feature_info(data, meta, feature_names, feature_types, enable_categorical)
#     407             new_feature_types.append(_pandas_dtype_mapper[dtype.name])
#     408         except KeyError:
# --> 409             _invalid_dataframe_dtype(data)
#     411 if feature_types is None and meta is None:
#     412     feature_types = new_feature_types
#
# File c:\Users\HP\Downloads\playground-series\.venv\Lib\site-packages\xgboost\data.py:372, in _invalid_dataframe_dtype(data)
#     370 type_err = "DataFrame.dtypes for data must be int, float, bool or category."
#     371 msg = f"""{type_err} {_ENABLE_CAT_ERR} {err}"""
# --> 372 raise ValueError(msg)
#
# ValueError: DataFrame.dtypes for data must be int, float, bool or category. When categorical type is supplied, the experimental DMatrix parameter`enable_categorical` must be set to `True`.  Invalid columns:date: object, country: object, store: object, product: object

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import xgboost as xgb
import warnings

warnings.filterwarnings('ignore')

train_data = "train.csv"
df = pd.read_csv(train_data)

df.isnull().sum()
df['num_sold'].fillna(0, inplace=True)
df.isnull().sum()

X = df.drop('num_sold', axis=1)

y = df['num_sold']

y.head()
# split X and y into training and testing sets

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.15, random_state = 0)
# import XGBClassifier
from xgboost import XGBClassifier


# declare parameters
params = {
            'objective':'reg:squarederror',
            'max_depth': 4,
            'alpha': 10,
            'learning_rate': 0.1,
            'n_estimators':100,
            'enable_categorical':True,
        }
            
            
            
# instantiate the classifier 
xgb_clf = XGBClassifier(**params)

from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
y_train = le.fit_transform(y_train)


# fit the classifier to the training data
xgb_clf.fit(X_train, y_train)

# make predictions on test data
y_pred = xgb_clf.predict(X_test)

# check accuracy score
from sklearn.metrics import accuracy_score

print('XGBoost model accuracy score: {0:0.4f}'. format(accuracy_score(y_test, y_pred)))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\HP\Downloads\playground-series\.venv\Lib\site-packages\xgboost\data.py:407, in pandas_feature_info(data, meta, feature_names, feature_types, enable_categorical)
#     406 try:
# --> 407     new_feature_types.append(_pandas_dtype_mapper[dtype.name])
#     408 except KeyError:
#
# KeyError: 'object'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 52
#      48 y_train = le.fit_transform(y_train)
#      51 # fit the classifier to the training data
# ---> 52 xgb_clf.fit(X_train, y_train)
#      54 # make predictions on test data
#      55 y_pred = xgb_clf.predict(X_test)
#
# File c:\Users\HP\Downloads\playground-series\.venv\Lib\site-packages\xgboost\core.py:729, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     727 for k, arg in zip(sig.parameters, args):
#     728     kwargs[k] = arg
# --> 729 return func(**kwargs)
#
# File c:\Users\HP\Downloads\playground-series\.venv\Lib\site-packages\xgboost\sklearn.py:1663, in XGBClassifier.fit(self, X, y, sample_weight, base_margin, eval_set, verbose, xgb_model, sample_weight_eval_set, base_margin_eval_set, feature_weights)
#    1658     params["num_class"] = self.n_classes_
#    1660 model, metric, params, feature_weights = self._configure_fit(
#    1661     xgb_model, params, feature_weights
#    1662 )
# -> 1663 train_dmatrix, evals = _wrap_evaluation_matrices(
#    1664     missing=self.missing,
#    1665     X=X,
#    1666     y=y,
#    1667     group=None,
#    1668     qid=None,
#    1669     sample_weight=sample_weight,
#    1670     base_margin=base_margin,
#    1671     feature_weights=feature_weights,
#    1672     eval_set=eval_set,
#    1673     sample_weight_eval_set=sample_weight_eval_set,
#    1674     base_margin_eval_set=base_margin_eval_set,
#    1675     eval_group=None,
#    1676     eval_qid=None,
#    1677     create_dmatrix=self._create_dmatrix,
#    1678     enable_categorical=self.enable_categorical,
#    1679     feature_types=self.feature_types,
#    1680 )
#    1682 self._Booster = train(
#    1683     params,
#    1684     train_dmatrix,
#    (...)   1693     callbacks=self.callbacks,
#    1694 )
#    1696 if not callable(self.objective):
#
# File c:\Users\HP\Downloads\playground-series\.venv\Lib\site-packages\xgboost\sklearn.py:628, in _wrap_evaluation_matrices(missing, X, y, group, qid, sample_weight, base_margin, feature_weights, eval_set, sample_weight_eval_set, base_margin_eval_set, eval_group, eval_qid, create_dmatrix, enable_categorical, feature_types)
#     607 def _wrap_evaluation_matrices(
#     608     *,
#     609     missing: float,
#    (...)    624     feature_types: Optional[FeatureTypes],
#     625 ) -> Tuple[Any, List[Tuple[Any, str]]]:
#     626     """Convert array_like evaluation matrices into DMatrix.  Perform validation on the
#     627     way."""
# --> 628     train_dmatrix = create_dmatrix(
#     629         data=X,
#     630         label=y,
#     631         group=group,
#     632         qid=qid,
#     633         weight=sample_weight,
#     634         base_margin=base_margin,
#     635         feature_weights=feature_weights,
#     636         missing=missing,
#     637         enable_categorical=enable_categorical,
#     638         feature_types=feature_types,
#     639         ref=None,
#     640     )
#     642     n_validation = 0 if eval_set is None else len(eval_set)
#     644     def validate_or_none(meta: Optional[Sequence], name: str) -> Sequence:
#
# File c:\Users\HP\Downloads\playground-series\.venv\Lib\site-packages\xgboost\sklearn.py:1137, in XGBModel._create_dmatrix(self, ref, **kwargs)
#    1135 if _can_use_qdm(self.tree_method, self.device) and self.booster != "gblinear":
#    1136     try:
# -> 1137         return QuantileDMatrix(
#    1138             **kwargs, ref=ref, nthread=self.n_jobs, max_bin=self.max_bin
#    1139         )
#    1140     except TypeError:  # `QuantileDMatrix` supports lesser types than DMatrix
#    1141         pass
#
# File c:\Users\HP\Downloads\playground-series\.venv\Lib\site-packages\xgboost\core.py:729, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     727 for k, arg in zip(sig.parameters, args):
#     728     kwargs[k] = arg
# --> 729 return func(**kwargs)
#
# File c:\Users\HP\Downloads\playground-series\.venv\Lib\site-packages\xgboost\core.py:1614, in QuantileDMatrix.__init__(self, data, label, weight, base_margin, missing, silent, feature_names, feature_types, nthread, max_bin, ref, group, qid, label_lower_bound, label_upper_bound, feature_weights, enable_categorical, max_quantile_batches, data_split_mode)
#    1594     if any(
#    1595         info is not None
#    1596         for info in (
#    (...)   1607         )
#    1608     ):
#    1609         raise ValueError(
#    1610             "If data iterator is used as input, data like label should be "
#    1611             "specified as batch argument."
#    1612         )
# -> 1614 self._init(
#    1615     data,
#    1616     ref=ref,
#    1617     label=label,
#    1618     weight=weight,
#    1619     base_margin=base_margin,
#    1620     group=group,
#    1621     qid=qid,
#    1622     label_lower_bound=label_lower_bound,
#    1623     label_upper_bound=label_upper_bound,
#    1624     feature_weights=feature_weights,
#    1625     feature_names=feature_names,
#    1626     feature_types=feature_types,
#    1627     enable_categorical=enable_categorical,
#    1628     max_quantile_blocks=max_quantile_batches,
#    1629 )
#
# File c:\Users\HP\Downloads\playground-series\.venv\Lib\site-packages\xgboost\core.py:1678, in QuantileDMatrix._init(self, data, ref, enable_categorical, max_quantile_blocks, **meta)
#    1663 config = make_jcargs(
#    1664     nthread=self.nthread,
#    1665     missing=self.missing,
#    1666     max_bin=self.max_bin,
#    1667     max_quantile_blocks=max_quantile_blocks,
#    1668 )
#    1669 ret = _LIB.XGQuantileDMatrixCreateFromCallback(
#    1670     None,
#    1671     it.proxy.handle,
#    (...)   1676     ctypes.byref(handle),
#    1677 )
# -> 1678 it.reraise()
#    1679 # delay check_call to throw intermediate exception first
#    1680 _check_call(ret)
#
# File c:\Users\HP\Downloads\playground-series\.venv\Lib\site-packages\xgboost\core.py:572, in DataIter.reraise(self)
#     570 exc = self._exception
#     571 self._exception = None
# --> 572 raise exc
#
# File c:\Users\HP\Downloads\playground-series\.venv\Lib\site-packages\xgboost\core.py:553, in DataIter._handle_exception(self, fn, dft_ret)
#     550     return dft_ret
#     552 try:
# --> 553     return fn()
#     554 except Exception as e:  # pylint: disable=broad-except
#     555     # Defer the exception in order to return 0 and stop the iteration.
#     556     # Exception inside a ctype callback function has no effect except
#     557     # for printing to stderr (doesn't stop the execution).
#     558     tb = sys.exc_info()[2]
#
# File c:\Users\HP\Downloads\playground-series\.venv\Lib\site-packages\xgboost\core.py:640, in DataIter._next_wrapper.<locals>.<lambda>()
#     638     self._temporary_data = None
#     639 # pylint: disable=not-callable
# --> 640 return self._handle_exception(lambda: int(self.next(input_data)), 0)
#
# File c:\Users\HP\Downloads\playground-series\.venv\Lib\site-packages\xgboost\data.py:1654, in SingleBatchInternalIter.next(self, input_data)
#    1652     return False
#    1653 self.it += 1
# -> 1654 input_data(**self.kwargs)
#    1655 return True
#
# File c:\Users\HP\Downloads\playground-series\.venv\Lib\site-packages\xgboost\core.py:729, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     727 for k, arg in zip(sig.parameters, args):
#     728     kwargs[k] = arg
# --> 729 return func(**kwargs)
#
# File c:\Users\HP\Downloads\playground-series\.venv\Lib\site-packages\xgboost\core.py:620, in DataIter._next_wrapper.<locals>.input_data(data, feature_names, feature_types, **kwargs)
#     618     new, cat_codes, feature_names, feature_types = self._temporary_data
#     619 else:
# --> 620     new, cat_codes, feature_names, feature_types = _proxy_transform(
#     621         data,
#     622         feature_names,
#     623         feature_types,
#     624         self._enable_categorical,
#     625     )
#     626 # Stage the data, meta info are copied inside C++ MetaInfo.
#     627 self._temporary_data = (new, cat_codes, feature_names, feature_types)
#
# File c:\Users\HP\Downloads\playground-series\.venv\Lib\site-packages\xgboost\data.py:1707, in _proxy_transform(data, feature_names, feature_types, enable_categorical)
#    1705     return df_pa, None, feature_names, feature_types
#    1706 if _is_pandas_df(data):
# -> 1707     df, feature_names, feature_types = _transform_pandas_df(
#    1708         data, enable_categorical, feature_names, feature_types
#    1709     )
#    1710     return df, None, feature_names, feature_types
#    1711 raise TypeError("Value type is not supported for data iterator:" + str(type(data)))
#
# File c:\Users\HP\Downloads\playground-series\.venv\Lib\site-packages\xgboost\data.py:640, in _transform_pandas_df(data, enable_categorical, feature_names, feature_types, meta)
#     637 if meta and len(data.columns) > 1 and meta not in _matrix_meta:
#     638     raise ValueError(f"DataFrame for {meta} cannot have multiple columns")
# --> 640 feature_names, feature_types = pandas_feature_info(
#     641     data, meta, feature_names, feature_types, enable_categorical
#     642 )
#     644 arrays = pandas_transform_data(data)
#     645 return PandasTransformed(arrays), feature_names, feature_types
#
# File c:\Users\HP\Downloads\playground-series\.venv\Lib\site-packages\xgboost\data.py:409, in pandas_feature_info(data, meta, feature_names, feature_types, enable_categorical)
#     407             new_feature_types.append(_pandas_dtype_mapper[dtype.name])
#     408         except KeyError:
# --> 409             _invalid_dataframe_dtype(data)
#     411 if feature_types is None and meta is None:
#     412     feature_types = new_feature_types
#
# File c:\Users\HP\Downloads\playground-series\.venv\Lib\site-packages\xgboost\data.py:372, in _invalid_dataframe_dtype(data)
#     370 type_err = "DataFrame.dtypes for data must be int, float, bool or category."
#     371 msg = f"""{type_err} {_ENABLE_CAT_ERR} {err}"""
# --> 372 raise ValueError(msg)
#
# ValueError: DataFrame.dtypes for data must be int, float, bool or category. When categorical type is supplied, the experimental DMatrix parameter`enable_categorical` must be set to `True`.  Invalid columns:date: object, country: object, store: object, product: object

# %% [markdown]
# Restarted .venv (Python 3.13.1)

# %%
pip install scikit-lego
# Out:
# Collecting scikit-lego
#   Downloading scikit_lego-0.9.5-py2.py3-none-any.whl.metadata (12 kB)
# Collecting narwhals>=1.5.0 (from scikit-lego)
#   Downloading narwhals-1.47.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: pandas>=1.1.5 in c:\users\hp\downloads\playground-series\.venv\lib\site-packages (from scikit-lego) (2.3.1)
# Requirement already satisfied: scikit-learn>=1.0 in c:\users\hp\downloads\playground-series\.venv\lib\site-packages (from scikit-lego) (1.7.0)
# Collecting sklearn-compat>=0.1.3 (from scikit-lego)
#   Downloading sklearn_compat-0.1.3-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\hp\downloads\playground-series\.venv\lib\site-packages (from pandas>=1.1.5->scikit-lego) (2.3.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\hp\downloads\playground-series\.venv\lib\site-packages (from pandas>=1.1.5->scikit-lego) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\hp\downloads\playground-series\.venv\lib\site-packages (from pandas>=1.1.5->scikit-lego) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\hp\downloads\playground-series\.venv\lib\site-packages (from pandas>=1.1.5->scikit-lego) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\hp\downloads\playground-series\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.1.5->scikit-lego) (1.17.0)
# Requirement already satisfied: scipy>=1.8.0 in c:\users\hp\downloads\playground-series\.venv\lib\site-packages (from scikit-learn>=1.0->scikit-lego) (1.16.0)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\hp\downloads\playground-series\.venv\lib\site-packages (from scikit-learn>=1.0->scikit-lego) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\hp\downloads\playground-series\.venv\lib\site-packages (from scikit-learn>=1.0->scikit-lego) (3.6.0)
# Collecting scikit-learn>=1.0 (from scikit-lego)
#   Downloading scikit_learn-1.6.1-cp313-cp313-win_amd64.whl.metadata (15 kB)
# Downloading scikit_lego-0.9.5-py2.py3-none-any.whl (224 kB)
# Downloading narwhals-1.47.0-py3-none-any.whl (374 kB)
# Downloading sklearn_compat-0.1.3-py3-none-any.whl (18 kB)
# Downloading scikit_learn-1.6.1-cp313-cp313-win_amd64.whl (11.1 MB)
#    ---------------------------------------- 0.0/11.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.1 MB ? eta -:--:--
#     --------------------------------------- 0.3/11.1 MB ? eta -:--:--
#     --------------------------------------- 0.3/11.1 MB ? eta -:--:--
#    - -------------------------------------- 0.5/11.1 MB 540.4 kB/s eta 0:00:20
#    - -------------------------------------- 0.5/11.1 MB 540.4 kB/s eta 0:00:20
#    - -------------------------------------- 0.5/11.1 MB 540.4 kB/s eta 0:00:20
#    - -------------------------------------- 0.5/11.1 MB 540.4 kB/s eta 0:00:20
#    - -------------------------------------- 0.5/11.1 MB 540.4 kB/s eta 0:00:20
#    -- ------------------------------------- 0.8/11.1 MB 378.2 kB/s eta 0:00:28
#    --- ------------------------------------ 1.0/11.1 MB 476.5 kB/s eta 0:00:22
#    ---- ----------------------------------- 1.3/11.1 MB 570.5 kB/s eta 0:00:18
#    ----- ---------------------------------- 1.6/11.1 MB 653.5 kB/s eta 0:00:15
#    ------- -------------------------------- 2.1/11.1 MB 802.7 kB/s eta 0:00:12
#    -------- ------------------------------- 2.4/11.1 MB 865.3 kB/s eta 0:00:11
#    ---------- ----------------------------- 2.9/11.1 MB 971.1 kB/s eta 0:00:09
#    ----------- ---------------------------- 3.1/11.1 MB 1.0 MB/s eta 0:00:08
#    ------------ --------------------------- 3.4/11.1 MB 1.0 MB/s eta 0:00:08
#    ------------- -------------------------- 3.7/11.1 MB 1.0 MB/s eta 0:00:08
#    ------------- -------------------------- 3.7/11.1 MB 1.0 MB/s eta 0:00:08
#    -------------- ------------------------- 3.9/11.1 MB 1.0 MB/s eta 0:00:07
#    --------------- ------------------------ 4.2/11.1 MB 1.0 MB/s eta 0:00:07
#    ---------------- ----------------------- 4.5/11.1 MB 1.0 MB/s eta 0:00:07
#    ----------------- ---------------------- 4.7/11.1 MB 1.0 MB/s eta 0:00:07
#    ----------------- ---------------------- 5.0/11.1 MB 1.1 MB/s eta 0:00:06
#    ------------------- -------------------- 5.5/11.1 MB 1.1 MB/s eta 0:00:06
#    -------------------- ------------------- 5.8/11.1 MB 1.1 MB/s eta 0:00:05
#    ---------------------- ----------------- 6.3/11.1 MB 1.2 MB/s eta 0:00:05
#    ----------------------- ---------------- 6.6/11.1 MB 1.2 MB/s eta 0:00:04
#    ------------------------- -------------- 7.1/11.1 MB 1.2 MB/s eta 0:00:04
#    -------------------------- ------------- 7.3/11.1 MB 1.2 MB/s eta 0:00:04
#    --------------------------- ------------ 7.6/11.1 MB 1.2 MB/s eta 0:00:03
#    --------------------------- ------------ 7.6/11.1 MB 1.2 MB/s eta 0:00:03
#    ---------------------------- ----------- 7.9/11.1 MB 1.2 MB/s eta 0:00:03
#    ------------------------------ --------- 8.4/11.1 MB 1.2 MB/s eta 0:00:03
#    ------------------------------- -------- 8.7/11.1 MB 1.3 MB/s eta 0:00:02
#    -------------------------------- ------- 8.9/11.1 MB 1.3 MB/s eta 0:00:02
#    ---------------------------------- ----- 9.4/11.1 MB 1.3 MB/s eta 0:00:02
#    ----------------------------------- ---- 9.7/11.1 MB 1.3 MB/s eta 0:00:02
#    ----------------------------------- ---- 10.0/11.1 MB 1.3 MB/s eta 0:00:01
#    ------------------------------------ --- 10.2/11.1 MB 1.3 MB/s eta 0:00:01
#    -------------------------------------- - 10.7/11.1 MB 1.3 MB/s eta 0:00:01
#    ---------------------------------------- 11.1/11.1 MB 1.3 MB/s eta 0:00:00
# Installing collected packages: narwhals, scikit-learn, sklearn-compat, scikit-lego
#
#    ---------------------------------------- 0/4 [narwhals]
#    ---------------------------------------- 0/4 [narwhals]
#    ---------------------------------------- 0/4 [narwhals]
#    ---------------------------------------- 0/4 [narwhals]
#    ---------------------------------------- 0/4 [narwhals]
#    ---------------------------------------- 0/4 [narwhals]
#    ---------------------------------------- 0/4 [narwhals]
#    ---------------------------------------- 0/4 [narwhals]
#    ---------------------------------------- 0/4 [narwhals]
#    ---------------------------------------- 0/4 [narwhals]
#    ---------------------------------------- 0/4 [narwhals]
#    ---------------------------------------- 0/4 [narwhals]
#    ---------------------------------------- 0/4 [narwhals]
#    ---------------------------------------- 0/4 [narwhals]
#    ---------------------------------------- 0/4 [narwhals]
#    ---------------------------------------- 0/4 [narwhals]
#    ---------------------------------------- 0/4 [narwhals]
#    ---------------------------------------- 0/4 [narwhals]
#    ---------------------------------------- 0/4 [narwhals]
#    ---------------------------------------- 0/4 [narwhals]
#   Attempting uninstall: scikit-learn
#    ---------------------------------------- 0/4 [narwhals]
#     Found existing installation: scikit-learn 1.7.0
#    ---------------------------------------- 0/4 [narwhals]
#    ---------- ----------------------------- 1/4 [scikit-learn]
#    ---------- ----------------------------- 1/4 [scikit-learn]
#    ---------- ----------------------------- 1/4 [scikit-learn]
#    ---------- ----------------------------- 1/4 [scikit-learn]
#     Uninstalling scikit-learn-1.7.0:
#    ---------- ----------------------------- 1/4 [scikit-learn]
#    ---------- ----------------------------- 1/4 [scikit-learn]
#       Successfully uninstalled scikit-learn-1.7.0
#    ---------- ----------------------------- 1/4 [scikit-learn]
#    ---------- ----------------------------- 1/4 [scikit-learn]
#    ---------- ----------------------------- 1/4 [scikit-learn]
#    ---------- ----------------------------- 1/4 [scikit-learn]
#    ---------- ----------------------------- 1/4 [scikit-learn]
#    ---------- ----------------------------- 1/4 [scikit-learn]
#    ---------- ----------------------------- 1/4 [scikit-learn]
#    ---------- ----------------------------- 1/4 [scikit-learn]
#    ---------- ----------------------------- 1/4 [scikit-learn]
#    ---------- ----------------------------- 1/4 [scikit-learn]
#    ---------- ----------------------------- 1/4 [scikit-learn]
#    ---------- ----------------------------- 1/4 [scikit-learn]
#    ---------- ----------------------------- 1/4 [scikit-learn]
#    ---------- ----------------------------- 1/4 [scikit-learn]
#    ---------- ----------------------------- 1/4 [scikit-learn]
#    ---------- ----------------------------- 1/4 [scikit-learn]
#    ---------- ----------------------------- 1/4 [scikit-learn]
#    ---------- ----------------------------- 1/4 [scikit-learn]
#    ---------- ----------------------------- 1/4 [scikit-learn]
#    ---------- ----------------------------- 1/4 [scikit-learn]
#    ---------- ----------------------------- 1/4 [scikit-learn]
#    ---------- ----------------------------- 1/4 [scikit-learn]
#    ---------- ----------------------------- 1/4 [scikit-learn]
#    ---------- ----------------------------- 1/4 [scikit-learn]
#    ---------- ----------------------------- 1/4 [scikit-learn]
#    ---------- ----------------------------- 1/4 [scikit-learn]
#    ---------- ----------------------------- 1/4 [scikit-learn]
#    ---------- ----------------------------- 1/4 [scikit-learn]
#    ---------- ----------------------------- 1/4 [scikit-learn]
#    ---------- ----------------------------- 1/4 [scikit-learn]
#    ---------- ----------------------------- 1/4 [scikit-learn]
#    ---------- ----------------------------- 1/4 [scikit-learn]
#    ---------- ----------------------------- 1/4 [scikit-learn]
#    ---------- ----------------------------- 1/4 [scikit-learn]
#    ---------- ----------------------------- 1/4 [scikit-learn]
#    ---------- ----------------------------- 1/4 [scikit-learn]
#    ---------- ----------------------------- 1/4 [scikit-learn]
#    ---------- ----------------------------- 1/4 [scikit-learn]
#    ---------- ----------------------------- 1/4 [scikit-learn]
#    ---------- ----------------------------- 1/4 [scikit-learn]
#    ---------- ----------------------------- 1/4 [scikit-learn]
#    ---------- ----------------------------- 1/4 [scikit-learn]
#    ---------- ----------------------------- 1/4 [scikit-learn]
#    ---------- ----------------------------- 1/4 [scikit-learn]
#    ---------- ----------------------------- 1/4 [scikit-learn]
#    ---------- ----------------------------- 1/4 [scikit-learn]
#    ---------- ----------------------------- 1/4 [scikit-learn]
#    ---------- ----------------------------- 1/4 [scikit-learn]
#    ---------- ----------------------------- 1/4 [scikit-learn]
#    ---------- ----------------------------- 1/4 [scikit-learn]
#    ---------- ----------------------------- 1/4 [scikit-learn]
#    ---------- ----------------------------- 1/4 [scikit-learn]
#    ---------- ----------------------------- 1/4 [scikit-learn]
#    ---------- ----------------------------- 1/4 [scikit-learn]
#    ---------- ----------------------------- 1/4 [scikit-learn]
#    ---------- ----------------------------- 1/4 [scikit-learn]
#    ---------- ----------------------------- 1/4 [scikit-learn]
#    ---------- ----------------------------- 1/4 [scikit-learn]
#    ---------- ----------------------------- 1/4 [scikit-learn]
#    ---------- ----------------------------- 1/4 [scikit-learn]
#    ---------- ----------------------------- 1/4 [scikit-learn]
#    ---------- ----------------------------- 1/4 [scikit-learn]
#    ---------- ----------------------------- 1/4 [scikit-learn]
#    ---------- ----------------------------- 1/4 [scikit-learn]
#    ---------- ----------------------------- 1/4 [scikit-learn]
#    ---------- ----------------------------- 1/4 [scikit-learn]
#    ---------- ----------------------------- 1/4 [scikit-learn]
#    ---------- ----------------------------- 1/4 [scikit-learn]
#    ---------- ----------------------------- 1/4 [scikit-learn]
#    ---------- ----------------------------- 1/4 [scikit-learn]
#    ---------- ----------------------------- 1/4 [scikit-learn]
#    ---------- ----------------------------- 1/4 [scikit-learn]
#    ---------- ----------------------------- 1/4 [scikit-learn]
#    ---------- ----------------------------- 1/4 [scikit-learn]
#    ---------- ----------------------------- 1/4 [scikit-learn]
#    ---------- ----------------------------- 1/4 [scikit-learn]
#    ---------- ----------------------------- 1/4 [scikit-learn]
#    ---------- ----------------------------- 1/4 [scikit-learn]
#    ---------- ----------------------------- 1/4 [scikit-learn]
#    ---------- ----------------------------- 1/4 [scikit-learn]
#    ---------- ----------------------------- 1/4 [scikit-learn]
#    ---------- ----------------------------- 1/4 [scikit-learn]
#    ---------- ----------------------------- 1/4 [scikit-learn]
#    ---------- ----------------------------- 1/4 [scikit-learn]
#    ---------- ----------------------------- 1/4 [scikit-learn]
#    ---------- ----------------------------- 1/4 [scikit-learn]
#    ---------- ----------------------------- 1/4 [scikit-learn]
#    ---------- ----------------------------- 1/4 [scikit-learn]
#    ---------- ----------------------------- 1/4 [scikit-learn]
#    ---------- ----------------------------- 1/4 [scikit-learn]
#    ---------- ----------------------------- 1/4 [scikit-learn]
#    ---------- ----------------------------- 1/4 [scikit-learn]
#    ---------- ----------------------------- 1/4 [scikit-learn]
#    ---------- ----------------------------- 1/4 [scikit-learn]
#    ---------- ----------------------------- 1/4 [scikit-learn]
#    ---------- ----------------------------- 1/4 [scikit-learn]
#    ---------- ----------------------------- 1/4 [scikit-learn]
#    ---------- ----------------------------- 1/4 [scikit-learn]
#    ---------- ----------------------------- 1/4 [scikit-learn]
#    ---------- ----------------------------- 1/4 [scikit-learn]
#    ---------- ----------------------------- 1/4 [scikit-learn]
#    ---------- ----------------------------- 1/4 [scikit-learn]
#    ---------- ----------------------------- 1/4 [scikit-learn]
#    ---------- ----------------------------- 1/4 [scikit-learn]
#    ---------- ----------------------------- 1/4 [scikit-learn]
#    ---------- ----------------------------- 1/4 [scikit-learn]
#    ---------- ----------------------------- 1/4 [scikit-learn]
#    ---------- ----------------------------- 1/4 [scikit-learn]
#    ---------- ----------------------------- 1/4 [scikit-learn]
#    ---------- ----------------------------- 1/4 [scikit-learn]
#    ---------- ----------------------------- 1/4 [scikit-learn]
#    ---------- ----------------------------- 1/4 [scikit-learn]
#    ---------- ----------------------------- 1/4 [scikit-learn]
#    ---------- ----------------------------- 1/4 [scikit-learn]
#    ---------- ----------------------------- 1/4 [scikit-learn]
#    ---------- ----------------------------- 1/4 [scikit-learn]
#    ---------- ----------------------------- 1/4 [scikit-learn]
#    ---------- ----------------------------- 1/4 [scikit-learn]
#    ---------- ----------------------------- 1/4 [scikit-learn]
#    ---------- ----------------------------- 1/4 [scikit-learn]
#    ---------- ----------------------------- 1/4 [scikit-learn]
#    ---------- ----------------------------- 1/4 [scikit-learn]
#    ---------- ----------------------------- 1/4 [scikit-learn]
#    ---------- ----------------------------- 1/4 [scikit-learn]
#    ---------- ----------------------------- 1/4 [scikit-learn]
#    ---------- ----------------------------- 1/4 [scikit-learn]
#    ---------- ----------------------------- 1/4 [scikit-learn]
#    ---------- ----------------------------- 1/4 [scikit-learn]
#    ---------- ----------------------------- 1/4 [scikit-learn]
#    ---------- ----------------------------- 1/4 [scikit-learn]
#    ---------- ----------------------------- 1/4 [scikit-learn]
#    ---------- ----------------------------- 1/4 [scikit-learn]
#    ---------- ----------------------------- 1/4 [scikit-learn]
#    ---------- ----------------------------- 1/4 [scikit-learn]
#    ---------- ----------------------------- 1/4 [scikit-learn]
#    ---------- ----------------------------- 1/4 [scikit-learn]
#    ---------- ----------------------------- 1/4 [scikit-learn]
#    ---------- ----------------------------- 1/4 [scikit-learn]
#    ---------- ----------------------------- 1/4 [scikit-learn]
#    -------------------- ------------------- 2/4 [sklearn-compat]
#    -------------------- ------------------- 2/4 [sklearn-compat]
#    ------------------------------ --------- 3/4 [scikit-lego]
#    ------------------------------ --------- 3/4 [scikit-lego]
#    ------------------------------ --------- 3/4 [scikit-lego]
#    ------------------------------ --------- 3/4 [scikit-lego]
#    ------------------------------ --------- 3/4 [scikit-lego]
#    ------------------------------ --------- 3/4 [scikit-lego]
#    ------------------------------ --------- 3/4 [scikit-lego]
#    ------------------------------ --------- 3/4 [scikit-lego]
#    ---------------------------------------- 4/4 [scikit-lego]
#
# Successfully installed narwhals-1.47.0 scikit-learn-1.6.1 scikit-lego-0.9.5 sklearn-compat-0.1.3
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\HP\Downloads\playground-series\.venv\Lib\site-packages\~klearn'.
#   You can safely remove it manually.

# %% [markdown]
# No kernel connected
